# %% [markdown]
# frequent value imputation

# %%
import pandas as pd

# %%
df=pd.read_excel("/content/drive/MyDrive/nmims/sem1/aiml/kshamta mam/03 09 24/categorical/train1.xlsx",usecols=['GarageQual','FireplaceQu','SalePrice'])

# %%
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64
